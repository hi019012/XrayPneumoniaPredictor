# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
import cv2
import numpy as np
from sklearn.metrics import accuracy_score
from collections import Counter

# %%
train_path='c:/Users/hi019012/Desktop/chest-xray-pneumonia/chest_xray/train' 
test_path='c:/Users/hi019012/Desktop/chest-xray-pneumonia/chest_xray/test'
val_path='c:/Users/hi019012/Desktop/chest-xray-pneumonia/chest_xray/val'

# %%
def plot_images(img_dir, top=10):
    all_img_dirs = os.listdir(img_dir)
    img_files = [os.path.join(img_dir, file) for file in all_img_dirs][:5]
    plt.figure(figsize=(10, 10))  
    for idx, img_path in enumerate(img_files):
        plt.subplot(5, 5, idx+1)
        img = plt.imread(img_path)
        plt.tight_layout()        
        plt.axis('off')
        plt.imshow(img, cmap='gray')

# %% [markdown]
# # PLOT DATA

# %% [markdown]
# ## Function Plot Image

# %%
def plot_images(img_dir, top=10):
    all_img_dirs = os.listdir(img_dir)
    img_files = [os.path.join(img_dir, file) for file in all_img_dirs][:5]
    plt.figure(figsize=(10, 10))  
    for idx, img_path in enumerate(img_files):
        plt.subplot(5, 5, idx+1)
        img = plt.imread(img_path)
        plt.tight_layout()        
        plt.axis('off')
        plt.imshow(img, cmap='gray')

# %% [markdown]
# ## Normal Label

# %%
plot_images(train_path+'/NORMAL')

# %% [markdown]
# ## Pneumonia Lable

# %%
plot_images(train_path+'/PNEUMONIA')

# %% [markdown]
# ## PLot Bar chart Diagram "Counter Label Data"

# %%
def plot_bar_chart_diagram(path_data):
  dic={}
  for emotion in  os.listdir(path_data):
    dem=0
    for x in os.listdir(path_data+"/"+emotion):
      dem+=1
    dic[emotion]=dem
  print(dic)
  barlist=plt.bar(range(len(dic)), list(dic.values()),tick_label=list(dic.keys()))
#set color
  plt.show()

# %% [markdown]
# ### Data Training Diagram

# %%
plot_bar_chart_diagram(train_path)
# Out:
# {'PNEUMONIA': 3875, 'NORMAL': 1341}

# %% [markdown]
# ### Data Testing Diagram

# %%
plot_bar_chart_diagram(test_path)
# Out:
# {'PNEUMONIA': 390, 'NORMAL': 234}

# %% [markdown]
# # Data Generator

# %%
batch_size = 32
target_size = (116,82)

train_datagen = ImageDataGenerator(rescale=1./255.0,
                                   validation_split=0.3,
                                   zoom_range=0.8,
                                  horizontal_flip=True,
                
                                  )
test_datagen=ImageDataGenerator(rescale = 1./255.0)

train_generator = train_datagen.flow_from_directory(
        train_path,
        target_size=target_size,
        batch_size=batch_size,
        subset="training",
        class_mode='binary')

val_generator = train_datagen.flow_from_directory(
        train_path,
        target_size=target_size,
        batch_size=batch_size,
        subset="validation",
        class_mode='binary')
test_generator=test_datagen.flow_from_directory(
        test_path,
        target_size=target_size,
        class_mode='binary',
        batch_size=batch_size,
        shuffle=False)
# Out:
# Found 3652 images belonging to 2 classes.
# Found 1564 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Training Model By CNN

# %% [markdown]
# ## Build Model CNN

# %%
input_shape = (116,82,3) # img_rows, img_colums, color_channels

# %%
# Build Model
model = models.Sequential()

model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Flatten())

model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 114, 80, 64)       1792
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 114, 80, 64)       36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 57, 40, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 57, 40, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 57, 40, 128)       73856
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 57, 40, 128)       147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 28, 20, 128)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 28, 20, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 20, 256)       295168
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 28, 20, 256)       590080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 10, 256)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 14, 10, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 10, 512)       1180160
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 10, 512)       2359808
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 5, 512)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 7, 5, 512)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 17920)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              18351104
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 23,037,505
# Trainable params: 23,037,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <p style="background-color:#252629;font-family:avenir next;color:#F1F3F4;font-size:200%;text-align:center;border-radius:25px 25px;">Plot Model</p>

# %%
# Compile Model
plot_model(model, to_file='model_1.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Compile Model

# %%
# Compile Model
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam( learning_rate=0.0001), metrics=['accuracy'],)

# %% [markdown]
# ## Training Model

# %%
earlystop =tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                          min_delta=0, 
                          patience=10, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.5, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)
# checkpoint=tf.keras.callbacks.ModelCheckpoint(
#      checkpoint_path, verbose=1, save_weights_only=True,
#     period=5
# )
weight_for_0 = (1.0 / 1341)*(5216/2.0)
weight_for_1 = (1.0 / 3875)*(5216/2.0)
print(weight_for_0,weight_for_1)
class_weight = {0: weight_for_0, 1: weight_for_1}
callback=[earlystop,reduce_lr]
history = model.fit(train_generator, epochs=100 ,verbose=1, validation_data=val_generator,callbacks=callback,class_weight=class_weight,)
# Out:
# 1.9448173005219984 0.6730322580645162
# Epoch 1/100
# 115/115 [==============================] - 62s 532ms/step - loss: 0.6934 - accuracy: 0.4244 - val_loss: 0.6847 - val_accuracy: 0.7430
# Epoch 2/100
# 115/115 [==============================] - 60s 526ms/step - loss: 0.6882 - accuracy: 0.5608 - val_loss: 0.6606 - val_accuracy: 0.7487
# Epoch 3/100
# 115/115 [==============================] - 60s 525ms/step - loss: 0.5743 - accuracy: 0.7087 - val_loss: 0.4699 - val_accuracy: 0.7986
# Epoch 4/100
# 115/115 [==============================] - 60s 522ms/step - loss: 0.4281 - accuracy: 0.8160 - val_loss: 0.3831 - val_accuracy: 0.8363
# Epoch 5/100
# 115/115 [==============================] - 60s 523ms/step - loss: 0.3894 - accuracy: 0.8330 - val_loss: 0.3564 - val_accuracy: 0.8370
# Epoch 6/100
# 115/115 [==============================] - 60s 527ms/step - loss: 0.3605 - accuracy: 0.8486 - val_loss: 0.4051 - val_accuracy: 0.8165
# Epoch 7/100
# 115/115 [==============================] - 61s 533ms/step - loss: 0.3349 - accuracy: 0.8609 - val_loss: 0.4280 - val_accuracy: 0.8043
# Epoch 8/100
# 115/115 [==============================] - 61s 528ms/step - loss: 0.3247 - accuracy: 0.8612 - val_loss: 0.3846 - val_accuracy: 0.8210
# Epoch 9/100
# 115/115 [==============================] - 59s 518ms/step - loss: 0.3320 - accuracy: 0.8669 - val_loss: 0.3421 - val_accuracy: 0.8536
# Epoch 10/100
# 115/115 [==============================] - 60s 526ms/step - loss: 0.3520 - accuracy: 0.8497 - val_loss: 0.3757 - val_accuracy: 0.8350
# Epoch 11/100
# 115/115 [==============================] - 60s 525ms/step - loss: 0.3079 - accuracy: 0.8751 - val_loss: 0.3422 - val_accuracy: 0.8606
# Epoch 12/100
# 115/115 [==============================] - 60s 526ms/step - loss: 0.3236 - accuracy: 0.8669 - val_loss: 0.3709 - val_accuracy: 0.8465
# Epoch 13/100
# 115/115 [==============================] - 60s 524ms/step - loss: 0.2792 - accuracy: 0.8836 - val_loss: 0.3379 - val_accuracy: 0.8453
# Epoch 14/100
# 115/115 [==============================] - 60s 519ms/step - loss: 0.2760 - accuracy: 0.8902 - val_loss: 0.3747 - val_accuracy: 0.8478
# Epoch 15/100
# 115/115 [==============================] - 60s 525ms/step - loss: 0.3005 - accuracy: 0.8716 - val_loss: 0.3240 - val_accuracy: 0.8676
# Epoch 16/100
# 115/115 [==============================] - 60s 527ms/step - loss: 0.2749 - accuracy: 0.8864 - val_loss: 0.2532 - val_accuracy: 0.8939
# Epoch 17/100
# 115/115 [==============================] - 61s 527ms/step - loss: 0.2719 - accuracy: 0.8872 - val_loss: 0.2608 - val_accuracy: 0.8958
# Epoch 18/100
# 115/115 [==============================] - 60s 525ms/step - loss: 0.2637 - accuracy: 0.8932 - val_loss: 0.3051 - val_accuracy: 0.8587
# Epoch 19/100
# 115/115 [==============================] - 60s 525ms/step - loss: 0.2578 - accuracy: 0.8981 - val_loss: 0.2472 - val_accuracy: 0.8958
# Epoch 20/100
# 115/115 [==============================] - 60s 525ms/step - loss: 0.2548 - accuracy: 0.8968 - val_loss: 0.2870 - val_accuracy: 0.8734
# Epoch 21/100
# 115/115 [==============================] - 61s 529ms/step - loss: 0.2749 - accuracy: 0.8836 - val_loss: 0.3157 - val_accuracy: 0.8753
# Epoch 22/100
# 115/115 [==============================] - 60s 524ms/step - loss: 0.2683 - accuracy: 0.8886 - val_loss: 0.2384 - val_accuracy: 0.9015
# Epoch 23/100
# 115/115 [==============================] - 60s 526ms/step - loss: 0.2414 - accuracy: 0.9012 - val_loss: 0.2392 - val_accuracy: 0.8996
# Epoch 24/100
# 115/115 [==============================] - 60s 520ms/step - loss: 0.2296 - accuracy: 0.9072 - val_loss: 0.2711 - val_accuracy: 0.8849
# Epoch 25/100
# 115/115 [==============================] - 61s 529ms/step - loss: 0.2382 - accuracy: 0.9012 - val_loss: 0.2788 - val_accuracy: 0.8862
# Epoch 26/100
# 115/115 [==============================] - 60s 525ms/step - loss: 0.2223 - accuracy: 0.9107 - val_loss: 0.2258 - val_accuracy: 0.9054
# Epoch 27/100
# 115/115 [==============================] - 61s 527ms/step - loss: 0.2371 - accuracy: 0.9033 - val_loss: 0.4245 - val_accuracy: 0.8191
# Epoch 28/100
# 115/115 [==============================] - 61s 530ms/step - loss: 0.2465 - accuracy: 0.8962 - val_loss: 0.4037 - val_accuracy: 0.8402
# Epoch 29/100
# 115/115 [==============================] - 60s 524ms/step - loss: 0.2289 - accuracy: 0.9080 - val_loss: 0.3498 - val_accuracy: 0.8395
# Epoch 30/100
# 115/115 [==============================] - 61s 530ms/step - loss: 0.2219 - accuracy: 0.9036 - val_loss: 0.3182 - val_accuracy: 0.8696
# Epoch 31/100
# 115/115 [==============================] - 59s 519ms/step - loss: 0.2313 - accuracy: 0.9025 - val_loss: 0.2865 - val_accuracy: 0.8785
# Epoch 32/100
# 115/115 [==============================] - 60s 527ms/step - loss: 0.2067 - accuracy: 0.9113 - val_loss: 0.2194 - val_accuracy: 0.9111
# Epoch 33/100
# 115/115 [==============================] - 60s 526ms/step - loss: 0.2013 - accuracy: 0.9159 - val_loss: 0.2831 - val_accuracy: 0.8855
# Epoch 34/100
# 115/115 [==============================] - 62s 544ms/step - loss: 0.2000 - accuracy: 0.9220 - val_loss: 0.2503 - val_accuracy: 0.8926
# Epoch 35/100
# 115/115 [==============================] - 61s 531ms/step - loss: 0.2050 - accuracy: 0.9140 - val_loss: 0.3070 - val_accuracy: 0.8728
# Epoch 36/100
# 115/115 [==============================] - 59s 517ms/step - loss: 0.2150 - accuracy: 0.9124 - val_loss: 0.3348 - val_accuracy: 0.8734
# Epoch 37/100
# 115/115 [==============================] - 60s 521ms/step - loss: 0.2044 - accuracy: 0.9162 - val_loss: 0.3370 - val_accuracy: 0.8555
# Epoch 38/100
# 115/115 [==============================] - 59s 517ms/step - loss: 0.1999 - accuracy: 0.9107 - val_loss: 0.2976 - val_accuracy: 0.8792
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 39/100
# 115/115 [==============================] - 60s 521ms/step - loss: 0.1900 - accuracy: 0.9154 - val_loss: 0.3575 - val_accuracy: 0.8421
# Epoch 40/100
# 115/115 [==============================] - 62s 539ms/step - loss: 0.1664 - accuracy: 0.9313 - val_loss: 0.2142 - val_accuracy: 0.9124
# Epoch 41/100
# 115/115 [==============================] - 61s 533ms/step - loss: 0.1806 - accuracy: 0.9252 - val_loss: 0.2379 - val_accuracy: 0.9060
# Epoch 42/100
# 115/115 [==============================] - 59s 518ms/step - loss: 0.1920 - accuracy: 0.9195 - val_loss: 0.2232 - val_accuracy: 0.9028
# Epoch 43/100
# 115/115 [==============================] - 59s 516ms/step - loss: 0.1695 - accuracy: 0.9304 - val_loss: 0.2017 - val_accuracy: 0.9169
# Epoch 44/100
# 115/115 [==============================] - 59s 513ms/step - loss: 0.1709 - accuracy: 0.9365 - val_loss: 0.2581 - val_accuracy: 0.8900
# Epoch 45/100
# 115/115 [==============================] - 60s 519ms/step - loss: 0.1792 - accuracy: 0.9242 - val_loss: 0.2099 - val_accuracy: 0.9156
# Epoch 46/100
# 115/115 [==============================] - 60s 517ms/step - loss: 0.1705 - accuracy: 0.9326 - val_loss: 0.2470 - val_accuracy: 0.8977
# Epoch 47/100
# 115/115 [==============================] - 59s 516ms/step - loss: 0.1662 - accuracy: 0.9302 - val_loss: 0.2644 - val_accuracy: 0.8881
# Epoch 48/100
# 115/115 [==============================] - 60s 521ms/step - loss: 0.1723 - accuracy: 0.9318 - val_loss: 0.1813 - val_accuracy: 0.9252
# Epoch 49/100
# 115/115 [==============================] - 60s 518ms/step - loss: 0.1676 - accuracy: 0.9299 - val_loss: 0.2049 - val_accuracy: 0.9118
# Epoch 50/100
# 115/115 [==============================] - 60s 521ms/step - loss: 0.1843 - accuracy: 0.9220 - val_loss: 0.1938 - val_accuracy: 0.9252
# Epoch 51/100
# 115/115 [==============================] - 59s 514ms/step - loss: 0.1714 - accuracy: 0.9291 - val_loss: 0.2125 - val_accuracy: 0.9118
# Epoch 52/100
# 115/115 [==============================] - 60s 522ms/step - loss: 0.1676 - accuracy: 0.9310 - val_loss: 0.2339 - val_accuracy: 0.9028
# Epoch 53/100
# 115/115 [==============================] - 59s 513ms/step - loss: 0.1579 - accuracy: 0.9337 - val_loss: 0.1897 - val_accuracy: 0.9316
# Epoch 54/100
# 115/115 [==============================] - 59s 518ms/step - loss: 0.1620 - accuracy: 0.9359 - val_loss: 0.1860 - val_accuracy: 0.9265
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 55/100
# 115/115 [==============================] - 59s 518ms/step - loss: 0.1618 - accuracy: 0.9326 - val_loss: 0.1970 - val_accuracy: 0.9188
# Epoch 56/100
# 115/115 [==============================] - 59s 517ms/step - loss: 0.1462 - accuracy: 0.9428 - val_loss: 0.2056 - val_accuracy: 0.9252
# Epoch 57/100
# 115/115 [==============================] - 59s 515ms/step - loss: 0.1522 - accuracy: 0.9373 - val_loss: 0.1902 - val_accuracy: 0.9290
# Epoch 58/100
# 115/115 [==============================] - 60s 520ms/step - loss: 0.1547 - accuracy: 0.9398 - val_loss: 0.2227 - val_accuracy: 0.9111
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping

# %%
models.save_model(model ,'./Diagnose_Pneumoinia.h5')

# %% [markdown]
# ## Evaluate Model

# %%
score = model.evaluate(val_generator) 
print('Test loss: ', score[0])
print('Test accuracy: ', score[1])
# Out:
# 49/49 [==============================] - 18s 375ms/step - loss: 0.1904 - accuracy: 0.9271
# Test loss:  0.19038328528404236
# Test accuracy:  0.927109956741333

# %%
score = model.evaluate(train_generator) 
print('Test loss: ', score[0])
print('Test accuracy: ', score[1])
# Out:
# 115/115 [==============================] - 41s 355ms/step - loss: 0.1598 - accuracy: 0.9348
# Test loss:  0.1598278135061264
# Test accuracy:  0.9348302483558655

# %%
score = model.evaluate(test_generator) 
print('Test loss: ', score[0])
print('Test accuracy: ', score[1])
# Out:
# 20/20 [==============================] - 5s 226ms/step - loss: 0.2198 - accuracy: 0.9183
# Test loss:  0.2197771817445755
# Test accuracy:  0.9182692170143127

# %%
# Show Train History
keys=history.history.keys()
print(keys)

def show_train_history(hisData,train,test): 
    plt.plot(hisData.history[train])
    plt.plot(hisData.history[test])
    plt.title('Training History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

show_train_history(history, 'loss', 'val_loss')
show_train_history(history, 'accuracy', 'val_accuracy')
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,ConfusionMatrixDisplay
y_pred = np.round(model.predict(test_generator))
y_true = test_generator.classes
y_labels = list(test_generator.class_indices.keys())
display(ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred), display_labels=['Normal', 'Pneumonia']).plot())
print(classification_report(y_true, y_pred, target_names=y_labels))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.91      0.87      0.89       234
#    PNEUMONIA       0.92      0.95      0.94       390
#
#     accuracy                           0.92       624
#    macro avg       0.92      0.91      0.91       624
# weighted avg       0.92      0.92      0.92       624

# %% [markdown]
# # Training Model By Convolution Layer+SVM(final Layer)

# %%
from keras.applications.vgg16 import VGG16 
# load the pretrained model 
layer_input = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
layer_input.trainable=False
# extract features 
model_pre = models.Sequential()
model_pre.add( layer_input)
model_pre.add(layers.Flatten())

# %%
X_train= model_pre.predict(train_generator) 
y_train=train_generator.classes

# %%
print(X.shape)
print(Y.shape)
# Out:
# (3652, 3072)
# (3652,)

# %%
from sklearn.svm import SVC
clf_SVM=SVC(C=100,kernel='rbf',class_weight='balanced')
clf_SVM.fit(X,Y)
# Out:
# SVC(C=100, class_weight='balanced')

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix,plot_roc_curve
print (classification_report(Y,clf_SVM.predict(X)))
plot_confusion_matrix(clf_SVM,X,Y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.93      0.81       939
#            1       0.97      0.87      0.92      2713
#
#     accuracy                           0.89      3652
#    macro avg       0.85      0.90      0.87      3652
# weighted avg       0.91      0.89      0.89      3652

# %%
X_test=model_pre.predict(test_generator)
Y_test=test_generator.classes

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix,plot_roc_curve
print (classification_report(Y_test,clf_SVM.predict(X_test)))
plot_confusion_matrix(clf_SVM,X_test,Y_test)
fig=plot_roc_curve(clf_SVM,X_test,Y_test)
plt.title("ROC CURVE")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.20      0.25       234
#            1       0.61      0.76      0.68       390
#
#     accuracy                           0.55       624
#    macro avg       0.47      0.48      0.46       624
# weighted avg       0.51      0.55      0.52       624
